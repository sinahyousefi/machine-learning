# %% [markdown]
# # 📦 Bag-to-Box Assignment Using 3 Box Categories

# %%
import pandas as pd
import numpy as np
from itertools import combinations

# %% [markdown]
# ## Step 1: Define Bags

# %%
bag_types = {
    "Mini": ["Chanel Mini", "Jacquemus Le Chiquito"],
    "Small": ["Chanel Small Flap", "LV Alma BB", "Gucci Mini Dionysus"],
    "Medium": ["Chanel Medium to Maxi Flap", "LV Speedy 25-35", "Bottega Jodie"],
    "Large": ["Dior Book Tote", "LV OnTheGo GM", "Goyard Artois"],
    "X-Large": ["Horizon 55", "Rimowa Cabin"]
}

bag_dimensions = {
    "Mini": (18, 10, 6, 0.4),
    "Small": (24, 15, 8, 0.6),
    "Medium": (30, 20, 12, 0.9),
    "Large": (40, 30, 15, 1.2),
    "X-Large": (55, 40, 25, 2.5)
}

bags_list = []
for bag_type, models in bag_types.items():
    for model in models:
        for _ in range(3):
            l, w, h, wt = bag_dimensions[bag_type]
            bags_list.append({
                "bag_name": model,
                "bag_type": bag_type,
                "length_cm": l,
                "width_cm": w,
                "height_cm": h,
                "weight_kg": wt,
                "volume_cm3": l * w * h
            })

bags_df = pd.DataFrame(bags_list)
bags_df.head()
# Out:
#                 bag_name bag_type  length_cm  width_cm  height_cm  weight_kg
# 0            Chanel Mini     Mini         18        10          6        0.4  \
# 1            Chanel Mini     Mini         18        10          6        0.4
# 2            Chanel Mini     Mini         18        10          6        0.4
# 3  Jacquemus Le Chiquito     Mini         18        10          6        0.4
# 4  Jacquemus Le Chiquito     Mini         18        10          6        0.4
#
#    volume_cm3
# 0        1080
# 1        1080
# 2        1080
# 3        1080
# 4        1080

# %% [markdown]
# ## Step 2: Define Boxes

# %%
inch_to_cm = 2.54
box_data = {
    "category": ["Extra Small"] * 4 + ["Small"] * 4 + ["Medium"] * 4 + ["Large"] * 4 + ["Extra Large"] * 4 + ['Giant'],
    "dimensions_in": [
        (8, 6, 2), (6, 4, 4), (11, 9, 1), (4, 4, 4),
        (8, 6, 5), (12, 9, 2), (9, 7, 3), (6, 6, 6),
        (13, 11, 2), (12, 9, 6), (13, 12, 4), (8, 8, 8),
        (12, 12, 7), (15, 11, 6), (14, 10, 7), (10, 10, 10),
        (16, 12, 9), (12, 10, 9), (18, 12, 6), (12, 12, 12),
        (22, 22, 22)
    ]
}

box_df = pd.DataFrame(box_data)
box_df[['length_in', 'width_in', 'height_in']] = pd.DataFrame(box_df['dimensions_in'].tolist(), index=box_df.index)
box_df['length_cm'] = box_df['length_in'] * inch_to_cm
box_df['width_cm'] = box_df['width_in'] * inch_to_cm
box_df['height_cm'] = box_df['height_in'] * inch_to_cm
box_df['volume_cm3'] = box_df['length_cm'] * box_df['width_cm'] * box_df['height_cm']
box_df['box_type'] = [f"{row.category[:2]}_{i+1}" for i, row in box_df.iterrows()]
box_df = box_df.sort_values("volume_cm3").reset_index(drop=True)
box_df.head()
# Out:
#       category dimensions_in  length_in  width_in  height_in  length_cm
# 0  Extra Small     (4, 4, 4)          4         4          4      10.16  \
# 1  Extra Small     (8, 6, 2)          8         6          2      20.32
# 2  Extra Small     (6, 4, 4)          6         4          4      15.24
# 3  Extra Small    (11, 9, 1)         11         9          1      27.94
# 4        Small     (9, 7, 3)          9         7          3      22.86
#
#    width_cm  height_cm   volume_cm3 box_type
# 0     10.16      10.16  1048.772096     Ex_4
# 1     15.24       5.08  1573.158144     Ex_1
# 2     10.16      10.16  1573.158144     Ex_2
# 3     22.86       2.54  1622.319336     Ex_3
# 4     17.78       7.62  3097.155096     Sm_7

# %%
# Optional: Add new bag
add_new_bag = True  # Toggle this
if add_new_bag:
    new_bag_name = "Burberry - Lambskin Quilted Card Case With Detachable Strap Black"
    new_length_cm = 4 * inch_to_cm
    new_width_cm = 1 * inch_to_cm
    new_height_cm = 3 * inch_to_cm
    new_weight_kg = 0.8
    new_bag_count = 1
    if new_length_cm < 21 and new_height_cm < 7 and new_width_cm < 13:
        new_bag_type = 'Mini'
    elif 21 <= new_length_cm < 27 and 7 <= new_height_cm < 10 and 13 <= new_width_cm < 18:
        new_bag_type = 'Small'
    elif 27 <= new_length_cm < 35 and 10 <= new_height_cm < 14 and 18 <= new_width_cm < 25:
        new_bag_type = 'Medium'
    elif 35 <= new_length_cm < 48 and 14 <= new_height_cm < 20 and 25 <= new_width_cm < 35:
        new_bag_type = 'Large'
    elif 48 <= new_length_cm and 20 <= new_height_cm and 35 <= new_width_cm:
        new_bag_type = 'X-Large'
    else:
        new_bag_type = 'Customized'
    for _ in range(new_bag_count):
        bags_list.append({
            "bag_name": new_bag_name,
            "bag_type": new_bag_type,
            "length_cm": new_length_cm,
            "width_cm": new_width_cm,
            "height_cm": new_height_cm,
            "weight_kg": new_weight_kg,
            "volume_cm3": new_length_cm * new_width_cm * new_height_cm
        })

bags_df = pd.DataFrame(bags_list)
bags_df.tail()
# Out:
#                                              bag_name    bag_type  length_cm
# 45                    LV Pegase 55 leather travel bag  Customized     39.116  \
# 46               Mini Devotion Leather Top Handle Bag  Customized     19.050
# 47  Burberry - Lambskin Quilted Card Case With Det...  Customized     10.160
# 48  Burberry - Lambskin Quilted Card Case With Det...  Customized     10.160
# 49  Burberry - Lambskin Quilted Card Case With Det...  Customized     10.160
#
#     width_cm  height_cm  weight_kg    volume_cm3
# 45    21.082     55.118        0.8  45452.701094
# 46     5.080     12.065        0.8   1167.578310
# 47     2.540      7.620        0.8    196.644768
# 48     2.540      7.620        0.8    196.644768
# 49     2.540      7.620        0.8    196.644768

# %%
bags_df = bags_df.iloc[:-1]
bags_df
# Out:
#                                              bag_name    bag_type  length_cm
# 0                                         Chanel Mini        Mini     18.000  \
# 1                                         Chanel Mini        Mini     18.000
# 2                                         Chanel Mini        Mini     18.000
# 3                               Jacquemus Le Chiquito        Mini     18.000
# 4                               Jacquemus Le Chiquito        Mini     18.000
# 5                               Jacquemus Le Chiquito        Mini     18.000
# 6                                   Chanel Small Flap       Small     24.000
# 7                                   Chanel Small Flap       Small     24.000
# 8                                   Chanel Small Flap       Small     24.000
# 9                                          LV Alma BB       Small     24.000
# 10                                         LV Alma BB       Small     24.000
# 11                                         LV Alma BB       Small     24.000
# 12                                Gucci Mini Dionysus       Small     24.000
# 13                                Gucci Mini Dionysus       Small     24.000
# 14                                Gucci Mini Dionysus       Small     24.000
# 15                         Chanel Medium to Maxi Flap      Medium     30.000
# 16                         Chanel Medium to Maxi Flap      Medium     30.000
# 17                         Chanel Medium to Maxi Flap      Medium     30.000
# 18                                    LV Speedy 25-35      Medium     30.000
# 19                                    LV Speedy 25-35      Medium     30.000
# 20                                    LV Speedy 25-35      Medium     30.000
# 21                                      Bottega Jodie      Medium     30.000
# 22                                      Bottega Jodie      Medium     30.000
# 23                                      Bottega Jodie      Medium     30.000
# 24                                     Dior Book Tote       Large     40.000
# 25                                     Dior Book Tote       Large     40.000
# 26                                     Dior Book Tote       Large     40.000
# 27                                      LV OnTheGo GM       Large     40.000
# 28                                      LV OnTheGo GM       Large     40.000
# 29                                      LV OnTheGo GM       Large     40.000
# 30                                      Goyard Artois       Large     40.000
# 31                                      Goyard Artois       Large     40.000
# 32                                      Goyard Artois       Large     40.000
# 33                                         Horizon 55     X-Large     55.000
# 34                                         Horizon 55     X-Large     55.000
# 35                                         Horizon 55     X-Large     55.000
# 36                                       Rimowa Cabin     X-Large     55.000
# 37                                       Rimowa Cabin     X-Large     55.000
# 38                                       Rimowa Cabin     X-Large     55.000
# 39          Dolce & Gabbana - Devotion Top-handle bag        Mini     19.050
# 40  Louis Vuitton - Speedy Bandoulière 30 Damier A...  Customized     29.972
# 41                         LV Safran Leather Milla PM  Customized     23.000
# 42  Saint Laurent - CASSANDRE ENVELOPE CHAIN WALLE...        Mini     19.000
# 43          LV mini cone decorated with the CASSANDRE        Mini     12.000
# 44                       LV The Speedy Bandoulière 20  Customized     20.574
# 45                    LV Pegase 55 leather travel bag  Customized     39.116
# 46               Mini Devotion Leather Top Handle Bag  Customized     19.050
# 47  Burberry - Lambskin Quilted Card Case With Det...  Customized     10.160
#
#     width_cm  height_cm  weight_kg    volume_cm3
# 0     10.000      6.000        0.4   1080.000000
# 1     10.000      6.000        0.4   1080.000000
# 2     10.000      6.000        0.4   1080.000000
# 3     10.000      6.000        0.4   1080.000000
# 4     10.000      6.000        0.4   1080.000000
# 5     10.000      6.000        0.4   1080.000000
# 6     15.000      8.000        0.6   2880.000000
# 7     15.000      8.000        0.6   2880.000000
# 8     15.000      8.000        0.6   2880.000000
# 9     15.000      8.000        0.6   2880.000000
# 10    15.000      8.000        0.6   2880.000000
# 11    15.000      8.000        0.6   2880.000000
# 12    15.000      8.000        0.6   2880.000000
# 13    15.000      8.000        0.6   2880.000000
# 14    15.000      8.000        0.6   2880.000000
# 15    20.000     12.000        0.9   7200.000000
# 16    20.000     12.000        0.9   7200.000000
# 17    20.000     12.000        0.9   7200.000000
# 18    20.000     12.000        0.9   7200.000000
# 19    20.000     12.000        0.9   7200.000000
# 20    20.000     12.000        0.9   7200.000000
# 21    20.000     12.000        0.9   7200.000000
# 22    20.000     12.000        0.9   7200.000000
# 23    20.000     12.000        0.9   7200.000000
# 24    30.000     15.000        1.2  18000.000000
# 25    30.000     15.000        1.2  18000.000000
# 26    30.000     15.000        1.2  18000.000000
# 27    30.000     15.000        1.2  18000.000000
# 28    30.000     15.000        1.2  18000.000000
# 29    30.000     15.000        1.2  18000.000000
# 30    30.000     15.000        1.2  18000.000000
# 31    30.000     15.000        1.2  18000.000000
# 32    30.000     15.000        1.2  18000.000000
# 33    40.000     25.000        2.5  55000.000000
# 34    40.000     25.000        2.5  55000.000000
# 35    40.000     25.000        2.5  55000.000000
# 36    40.000     25.000        2.5  55000.000000
# 37    40.000     25.000        2.5  55000.000000
# 38    40.000     25.000        2.5  55000.000000
# 39    12.954      4.318        0.8   1065.568837
# 40    21.082     17.018        1.8  10753.158623
# 41    14.000     21.000        1.8   6762.000000
# 42    12.500      3.500        0.8    831.250000
# 43     7.500      4.000        0.8    360.000000
# 44    11.938     13.462        0.8   3306.434290
# 45    21.082     55.118        0.8  45452.701094
# 46     5.080     12.065        0.8   1167.578310
# 47     2.540      7.620        0.8    196.644768

# %% [markdown]
# ## Step 3: Choose One Smallest Box From Each Category (3 Categories)

# %%
# Choose combinations of 3 box *categories*, and pick the smallest from each
box_df_filtered = box_df.copy()
category_combos = list(combinations(box_df_filtered['box_type'].unique(), 3))
results = []
n = 100000000
print(len(category_combos))
for categories in category_combos:
    selected_boxes = box_df_filtered[box_df_filtered['box_type'].isin(categories)]
    rep_boxes = (selected_boxes.sort_values('volume_cm3').groupby('box_type', as_index=False).first().sort_values('volume_cm3').reset_index(drop=True))

    largest_bag_dims = (np.max(bags_df["length_cm"]), np.max(bags_df["width_cm"]), np.max(bags_df["height_cm"]))
    
    if not any(
        (rep_boxes["length_cm"] >= largest_bag_dims[0]) &
        (rep_boxes["width_cm"] >= largest_bag_dims[1]) &
        (rep_boxes["height_cm"] >= largest_bag_dims[2])
    ):
        continue

    assigned = []
    box_counts = {'cost': 0, **{box: 0 for box in rep_boxes['box_type']}}
    
    # print(rep_boxes)

    for i in range(len(bags_df)):
        if (rep_boxes['length_cm'][0] >= bags_df.iloc[i]['length_cm']) & (rep_boxes['width_cm'][0] >= bags_df.iloc[i]['width_cm']) & (rep_boxes['height_cm'][0] >= bags_df.iloc[i]['height_cm']):
            box_counts[rep_boxes['box_type'][0]] += 1
            box_counts['cost'] += rep_boxes['volume_cm3'][0]
        elif (rep_boxes['length_cm'][1] >= bags_df.iloc[i]['length_cm']) & (rep_boxes['width_cm'][1] >= bags_df.iloc[i]['width_cm']) & (rep_boxes['height_cm'][1] >= bags_df.iloc[i]['height_cm']): 
            box_counts[rep_boxes['box_type'][1]] += 1
            box_counts['cost'] += rep_boxes['volume_cm3'][1]
        elif (rep_boxes['length_cm'][2] >= bags_df.iloc[i]['length_cm']) & (rep_boxes['width_cm'][2] >= bags_df.iloc[i]['width_cm']) & (rep_boxes['height_cm'][2] >= bags_df.iloc[i]['height_cm']): 
            box_counts[rep_boxes['box_type'][2]] += 1
            box_counts['cost'] += rep_boxes['volume_cm3'][2]
              
    if box_counts["cost"] < n:
        n = box_counts["cost"]
        results = box_counts

print(results)
# Out:
# 1330
# {'cost': 1851476.0389759995, 'Me_10': 30, 'Ex_17': 11, 'Gi_21': 7}

# %% [markdown]
# ## Step 4: Results
